# %%
import sys
# !{sys.executable} -m pip install mlxtend
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting mlxtend
#   Using cached mlxtend-0.24.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: scipy>=1.16.3 in c:\users\sdbi\appdata\roaming\python\python313\site-packages (from mlxtend) (1.17.1)
# Requirement already satisfied: numpy>=2.3.5 in c:\users\sdbi\appdata\roaming\python\python313\site-packages (from mlxtend) (2.4.5)
# Requirement already satisfied: pandas>=2.3.3 in c:\users\sdbi\appdata\roaming\python\python313\site-packages (from mlxtend) (3.0.3)
# Requirement already satisfied: scikit-learn>=1.8.0 in c:\users\sdbi\appdata\roaming\python\python313\site-packages (from mlxtend) (1.8.0)
# Collecting matplotlib>=3.10.8 (from mlxtend)
#   Using cached matplotlib-3.10.9-cp313-cp313-win_amd64.whl.metadata (52 kB)
# Requirement already satisfied: joblib>=1.5.2 in c:\users\sdbi\appdata\roaming\python\python313\site-packages (from mlxtend) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (24.2)
# Requirement already satisfied: pillow>=8 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (11.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\programdata\anaconda3\lib\site-packages (from pandas>=2.3.3->mlxtend) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.10.8->mlxtend) (1.17.0)
# Using cached mlxtend-0.24.0-py3-none-any.whl (1.4 MB)
# Using cached matplotlib-3.10.9-cp313-cp313-win_amd64.whl (8.2 MB)
# Installing collected packages: matplotlib, mlxtend
#
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    ---------------------------------------- 0/2 [matplotlib]
#    -------------------- ------------------- 1/2 [mlxtend]
#    -------------------- ------------------- 1/2 [mlxtend]
#    -------------------- ------------------- 1/2 [mlxtend]
#    -------------------- ------------------- 1/2 [mlxtend]
#    -------------------- ------------------- 1/2 [mlxtend]
#    -------------------- ------------------- 1/2 [mlxtend]
#    -------------------- ------------------- 1/2 [mlxtend]
#    -------------------- ------------------- 1/2 [mlxtend]
#    -------------------- ------------------- 1/2 [mlxtend]
#    -------------------- ------------------- 1/2 [mlxtend]
#    -------------------- ------------------- 1/2 [mlxtend]
#    ---------------------------------------- 2/2 [mlxtend]
#
# Successfully installed matplotlib-3.10.9 mlxtend-0.24.0

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# ---------------------------------------------------
# Transaction Dataset
# ---------------------------------------------------

transactions = [
    ['Bread', 'Milk'],
    ['Bread', 'Diaper', 'Beer', 'Eggs'],
    ['Milk', 'Diaper', 'Beer', 'Cola'],
    ['Bread', 'Milk', 'Diaper', 'Beer'],
    ['Bread', 'Milk', 'Diaper', 'Cola']
]

# ---------------------------------------------------
# Convert Transactions into DataFrame
# ---------------------------------------------------

te = TransactionEncoder()

te_array = te.fit(transactions).transform(transactions)

df = pd.DataFrame(te_array, columns=te.columns_)

print("Transaction Data")
print(df)

# ---------------------------------------------------
# Apply Apriori Algorithm
# ---------------------------------------------------

frequent_itemsets = apriori(
    df,
    min_support=0.4,
    use_colnames=True
)

print("\nFrequent Itemsets")
print(frequent_itemsets)

# ---------------------------------------------------
# Generate Association Rules
# ---------------------------------------------------

rules = association_rules(
    frequent_itemsets,
    metric="confidence",
    min_threshold=0.5
)

print("\nAssociation Rules")
print(rules)

# ---------------------------------------------------
# Display Important Columns
# ---------------------------------------------------

print("\nSelected Rule Metrics")

print(
    rules[
        [
            'antecedents',
            'consequents',
            'support',
            'confidence',
            'lift'
        ]
    ]
)
# Out:
# C:\Users\SDBI\AppData\Roaming\Python\Python313\site-packages\pandas\core\computation\expressions.py:23: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.10.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# Transaction Data
#     Beer  Bread   Cola  Diaper   Eggs   Milk
# 0  False   True  False   False  False   True
# 1   True   True  False    True   True  False
# 2   True  False   True    True  False   True
# 3   True   True  False    True  False   True
# 4  False   True   True    True  False   True
#
# Frequent Itemsets
#     support                          itemsets
# 0       0.6                 frozenset({Beer})
# 1       0.8                frozenset({Bread})
# 2       0.4                 frozenset({Cola})
# 3       0.8               frozenset({Diaper})
# 4       0.8                 frozenset({Milk})
# 5       0.4          frozenset({Bread, Beer})
# 6       0.6         frozenset({Beer, Diaper})
# 7       0.4           frozenset({Milk, Beer})
# 8       0.6        frozenset({Bread, Diaper})
# 9       0.6          frozenset({Milk, Bread})
# 10      0.4         frozenset({Cola, Diaper})
# 11      0.4           frozenset({Milk, Cola})
# 12      0.6         frozenset({Milk, Diaper})
# 13      0.4  frozenset({Bread, Beer, Diaper})
# 14      0.4   frozenset({Milk, Beer, Diaper})
# 15      0.4  frozenset({Milk, Bread, Diaper})
# 16      0.4   frozenset({Milk, Cola, Diaper})
#
# Association Rules
#                    antecedents                 consequents  \
# 0           frozenset({Bread})           frozenset({Beer})
# 1            frozenset({Beer})          frozenset({Bread})
# 2            frozenset({Beer})         frozenset({Diaper})
# 3          frozenset({Diaper})           frozenset({Beer})
# 4            frozenset({Milk})           frozenset({Beer})
# 5            frozenset({Beer})           frozenset({Milk})
# 6           frozenset({Bread})         frozenset({Diaper})
# 7          frozenset({Diaper})          frozenset({Bread})
# 8            frozenset({Milk})          frozenset({Bread})
# 9           frozenset({Bread})           frozenset({Milk})
# 10           frozenset({Cola})         frozenset({Diaper})
# 11         frozenset({Diaper})           frozenset({Cola})
# 12           frozenset({Milk})           frozenset({Cola})
# 13           frozenset({Cola})           frozenset({Milk})
# 14           frozenset({Milk})         frozenset({Diaper})
# 15         frozenset({Diaper})           frozenset({Milk})
# 16    frozenset({Bread, Beer})         frozenset({Diaper})
# 17  frozenset({Bread, Diaper})           frozenset({Beer})
# 18   frozenset({Beer, Diaper})          frozenset({Bread})
# 19          frozenset({Bread})   frozenset({Beer, Diaper})
# 20           frozenset({Beer})  frozenset({Bread, Diaper})
# 21         frozenset({Diaper})    frozenset({Bread, Beer})
# 22     frozenset({Milk, Beer})         frozenset({Diaper})
# 23   frozenset({Milk, Diaper})           frozenset({Beer})
# 24   frozenset({Beer, Diaper})           frozenset({Milk})
# 25           frozenset({Milk})   frozenset({Beer, Diaper})
# 26           frozenset({Beer})   frozenset({Milk, Diaper})
# 27         frozenset({Diaper})     frozenset({Milk, Beer})
# 28    frozenset({Milk, Bread})         frozenset({Diaper})
# 29   frozenset({Milk, Diaper})          frozenset({Bread})
# 30  frozenset({Bread, Diaper})           frozenset({Milk})
# 31           frozenset({Milk})  frozenset({Bread, Diaper})
# 32          frozenset({Bread})   frozenset({Milk, Diaper})
# 33         frozenset({Diaper})    frozenset({Milk, Bread})
# 34     frozenset({Milk, Cola})         frozenset({Diaper})
# 35   frozenset({Milk, Diaper})           frozenset({Cola})
# 36   frozenset({Cola, Diaper})           frozenset({Milk})
# 37           frozenset({Milk})   frozenset({Cola, Diaper})
# 38           frozenset({Cola})   frozenset({Milk, Diaper})
# 39         frozenset({Diaper})     frozenset({Milk, Cola})
#
#     antecedent support  consequent support  support  confidence      lift  \
# 0                  0.8                 0.6      0.4    0.500000  0.833333
# 1                  0.6                 0.8      0.4    0.666667  0.833333
# 2                  0.6                 0.8      0.6    1.000000  1.250000
# 3                  0.8                 0.6      0.6    0.750000  1.250000
# 4                  0.8                 0.6      0.4    0.500000  0.833333
# 5                  0.6                 0.8      0.4    0.666667  0.833333
# 6                  0.8                 0.8      0.6    0.750000  0.937500
# 7                  0.8                 0.8      0.6    0.750000  0.937500
# 8                  0.8                 0.8      0.6    0.750000  0.937500
# 9                  0.8                 0.8      0.6    0.750000  0.937500
# 10                 0.4                 0.8      0.4    1.000000  1.250000
# 11                 0.8                 0.4      0.4    0.500000  1.250000
# 12                 0.8                 0.4      0.4    0.500000  1.250000
# 13                 0.4                 0.8      0.4    1.000000  1.250000
# 14                 0.8                 0.8      0.6    0.750000  0.937500
# 15                 0.8                 0.8      0.6    0.750000  0.937500
# 16                 0.4                 0.8      0.4    1.000000  1.250000
# 17                 0.6                 0.6      0.4    0.666667  1.111111
# 18                 0.6                 0.8      0.4    0.666667  0.833333
# 19                 0.8                 0.6      0.4    0.500000  0.833333
# 20                 0.6                 0.6      0.4    0.666667  1.111111
# 21                 0.8                 0.4      0.4    0.500000  1.250000
# 22                 0.4                 0.8      0.4    1.000000  1.250000
# 23                 0.6                 0.6      0.4    0.666667  1.111111
# 24                 0.6                 0.8      0.4    0.666667  0.833333
# 25                 0.8                 0.6      0.4    0.500000  0.833333
# 26                 0.6                 0.6      0.4    0.666667  1.111111
# 27                 0.8                 0.4      0.4    0.500000  1.250000
# 28                 0.6                 0.8      0.4    0.666667  0.833333
# 29                 0.6                 0.8      0.4    0.666667  0.833333
# 30                 0.6                 0.8      0.4    0.666667  0.833333
# 31                 0.8                 0.6      0.4    0.500000  0.833333
# 32                 0.8                 0.6      0.4    0.500000  0.833333
# 33                 0.8                 0.6      0.4    0.500000  0.833333
# 34                 0.4                 0.8      0.4    1.000000  1.250000
# 35                 0.6                 0.4      0.4    0.666667  1.666667
# 36                 0.4                 0.8      0.4    1.000000  1.250000
# 37                 0.8                 0.4      0.4    0.500000  1.250000
# 38                 0.4                 0.6      0.4    1.000000  1.666667
# 39                 0.8                 0.4      0.4    0.500000  1.250000
#
#     representativity  leverage  conviction  zhangs_metric   jaccard  \
# 0                1.0     -0.08         0.8      -0.500000  0.400000
# 1                1.0     -0.08         0.6      -0.333333  0.400000
# 2                1.0      0.12         inf       0.500000  0.750000
# 3                1.0      0.12         1.6       1.000000  0.750000
# 4                1.0     -0.08         0.8      -0.500000  0.400000
# 5                1.0     -0.08         0.6      -0.333333  0.400000
# 6                1.0     -0.04         0.8      -0.250000  0.600000
# 7                1.0     -0.04         0.8      -0.250000  0.600000
# 8                1.0     -0.04         0.8      -0.250000  0.600000
# 9                1.0     -0.04         0.8      -0.250000  0.600000
# 10               1.0      0.08         inf       0.333333  0.500000
# 11               1.0      0.08         1.2       1.000000  0.500000
# 12               1.0      0.08         1.2       1.000000  0.500000
# 13               1.0      0.08         inf       0.333333  0.500000
# 14               1.0     -0.04         0.8      -0.250000  0.600000
# 15               1.0     -0.04         0.8      -0.250000  0.600000
# 16               1.0      0.08         inf       0.333333  0.500000
# 17               1.0      0.04         1.2       0.250000  0.500000
# 18               1.0     -0.08         0.6      -0.333333  0.400000
# 19               1.0     -0.08         0.8      -0.500000  0.400000
# 20               1.0      0.04         1.2       0.250000  0.500000
# 21               1.0      0.08         1.2       1.000000  0.500000
# 22               1.0      0.08         inf       0.333333  0.500000
# 23               1.0      0.04         1.2       0.250000  0.500000
# 24               1.0     -0.08         0.6      -0.333333  0.400000
# 25               1.0     -0.08         0.8      -0.500000  0.400000
# 26               1.0      0.04         1.2       0.250000  0.500000
# 27               1.0      0.08         1.2       1.000000  0.500000
# 28               1.0     -0.08         0.6      -0.333333  0.400000
# 29               1.0     -0.08         0.6      -0.333333  0.400000
# 30               1.0     -0.08         0.6      -0.333333  0.400000
# 31               1.0     -0.08         0.8      -0.500000  0.400000
# 32               1.0     -0.08         0.8      -0.500000  0.400000
# 33               1.0     -0.08         0.8      -0.500000  0.400000
# 34               1.0      0.08         inf       0.333333  0.500000
# 35               1.0      0.16         1.8       1.000000  0.666667
# 36               1.0      0.08         inf       0.333333  0.500000
# 37               1.0      0.08         1.2       1.000000  0.500000
# 38               1.0      0.16         inf       0.666667  0.666667
# 39               1.0      0.08         1.2       1.000000  0.500000
#
#     certainty  kulczynski
# 0   -0.250000    0.583333
# 1   -0.666667    0.583333
# 2    1.000000    0.875000
# 3    0.375000    0.875000
# 4   -0.250000    0.583333
# 5   -0.666667    0.583333
# 6   -0.250000    0.750000
# 7   -0.250000    0.750000
# 8   -0.250000    0.750000
# 9   -0.250000    0.750000
# 10   1.000000    0.750000
# 11   0.166667    0.750000
# 12   0.166667    0.750000
# 13   1.000000    0.750000
# 14  -0.250000    0.750000
# 15  -0.250000    0.750000
# 16   1.000000    0.750000
# 17   0.166667    0.666667
# 18  -0.666667    0.583333
# 19  -0.250000    0.583333
# 20   0.166667    0.666667
# 21   0.166667    0.750000
# 22   1.000000    0.750000
# 23   0.166667    0.666667
# 24  -0.666667    0.583333
# 25  -0.250000    0.583333
# 26   0.166667    0.666667
# 27   0.166667    0.750000
# 28  -0.666667    0.583333
# 29  -0.666667    0.583333
# 30  -0.666667    0.583333
# 31  -0.250000    0.583333
# 32  -0.250000    0.583333
# 33  -0.250000    0.583333
# 34   1.000000    0.750000
# 35   0.444444    0.833333
# 36   1.000000    0.750000
# 37   0.166667    0.750000
# 38   1.000000    0.833333
# 39   0.166667    0.750000
#
# Selected Rule Metrics
#                    antecedents                 consequents  support  \
# 0           frozenset({Bread})           frozenset({Beer})      0.4
# 1            frozenset({Beer})          frozenset({Bread})      0.4
# 2            frozenset({Beer})         frozenset({Diaper})      0.6
# 3          frozenset({Diaper})           frozenset({Beer})      0.6
# 4            frozenset({Milk})           frozenset({Beer})      0.4
# 5            frozenset({Beer})           frozenset({Milk})      0.4
# 6           frozenset({Bread})         frozenset({Diaper})      0.6
# 7          frozenset({Diaper})          frozenset({Bread})      0.6
# 8            frozenset({Milk})          frozenset({Bread})      0.6
# 9           frozenset({Bread})           frozenset({Milk})      0.6
# 10           frozenset({Cola})         frozenset({Diaper})      0.4
# 11         frozenset({Diaper})           frozenset({Cola})      0.4
# 12           frozenset({Milk})           frozenset({Cola})      0.4
# 13           frozenset({Cola})           frozenset({Milk})      0.4
# 14           frozenset({Milk})         frozenset({Diaper})      0.6
# 15         frozenset({Diaper})           frozenset({Milk})      0.6
# 16    frozenset({Bread, Beer})         frozenset({Diaper})      0.4
# 17  frozenset({Bread, Diaper})           frozenset({Beer})      0.4
# 18   frozenset({Beer, Diaper})          frozenset({Bread})      0.4
# 19          frozenset({Bread})   frozenset({Beer, Diaper})      0.4
# 20           frozenset({Beer})  frozenset({Bread, Diaper})      0.4
# 21         frozenset({Diaper})    frozenset({Bread, Beer})      0.4
# 22     frozenset({Milk, Beer})         frozenset({Diaper})      0.4
# 23   frozenset({Milk, Diaper})           frozenset({Beer})      0.4
# 24   frozenset({Beer, Diaper})           frozenset({Milk})      0.4
# 25           frozenset({Milk})   frozenset({Beer, Diaper})      0.4
# 26           frozenset({Beer})   frozenset({Milk, Diaper})      0.4
# 27         frozenset({Diaper})     frozenset({Milk, Beer})      0.4
# 28    frozenset({Milk, Bread})         frozenset({Diaper})      0.4
# 29   frozenset({Milk, Diaper})          frozenset({Bread})      0.4
# 30  frozenset({Bread, Diaper})           frozenset({Milk})      0.4
# 31           frozenset({Milk})  frozenset({Bread, Diaper})      0.4
# 32          frozenset({Bread})   frozenset({Milk, Diaper})      0.4
# 33         frozenset({Diaper})    frozenset({Milk, Bread})      0.4
# 34     frozenset({Milk, Cola})         frozenset({Diaper})      0.4
# 35   frozenset({Milk, Diaper})           frozenset({Cola})      0.4
# 36   frozenset({Cola, Diaper})           frozenset({Milk})      0.4
# 37           frozenset({Milk})   frozenset({Cola, Diaper})      0.4
# 38           frozenset({Cola})   frozenset({Milk, Diaper})      0.4
# 39         frozenset({Diaper})     frozenset({Milk, Cola})      0.4
#
#     confidence      lift
# 0     0.500000  0.833333
# 1     0.666667  0.833333
# 2     1.000000  1.250000
# 3     0.750000  1.250000
# 4     0.500000  0.833333
# 5     0.666667  0.833333
# 6     0.750000  0.937500
# 7     0.750000  0.937500
# 8     0.750000  0.937500
# 9     0.750000  0.937500
# 10    1.000000  1.250000
# 11    0.500000  1.250000
# 12    0.500000  1.250000
# 13    1.000000  1.250000
# 14    0.750000  0.937500
# 15    0.750000  0.937500
# 16    1.000000  1.250000
# 17    0.666667  1.111111
# 18    0.666667  0.833333
# 19    0.500000  0.833333
# 20    0.666667  1.111111
# 21    0.500000  1.250000
# 22    1.000000  1.250000
# 23    0.666667  1.111111
# 24    0.666667  0.833333
# 25    0.500000  0.833333
# 26    0.666667  1.111111
# 27    0.500000  1.250000
# 28    0.666667  0.833333
# 29    0.666667  0.833333
# 30    0.666667  0.833333
# 31    0.500000  0.833333
# 32    0.500000  0.833333
# 33    0.500000  0.833333
# 34    1.000000  1.250000
# 35    0.666667  1.666667
# 36    1.000000  1.250000
# 37    0.500000  1.250000
# 38    1.000000  1.666667
# 39    0.500000  1.250000
